# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
df = pd.read_csv("Unemployment in India.csv")
df
# Out:
#              Region         Date  Frequency   Estimated Unemployment Rate (%)
# 0    Andhra Pradesh   31-05-2019    Monthly                              3.65  \
# 1    Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2    Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3    Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4    Andhra Pradesh   30-09-2019    Monthly                              5.17
# ..              ...          ...        ...                               ...
# 763             NaN          NaN        NaN                               NaN
# 764             NaN          NaN        NaN                               NaN
# 765             NaN          NaN        NaN                               NaN
# 766             NaN          NaN        NaN                               NaN
# 767             NaN          NaN        NaN                               NaN
#
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of              Region         Date  Frequency   Estimated Unemployment Rate (%)
# 0    Andhra Pradesh   31-05-2019    Monthly                              3.65  \
# 1    Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2    Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3    Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4    Andhra Pradesh   30-09-2019    Monthly                              5.17
# ..              ...          ...        ...                               ...
# 763             NaN          NaN        NaN                               NaN
# 764             NaN          NaN        NaN                               NaN
# 765             NaN          NaN        NaN                               NaN
# 766             NaN          NaN        NaN                               NaN
# 767             NaN          NaN        NaN                               NaN
#
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of              Region         Date  Frequency   Estimated Unemployment Rate (%)
# 0    Andhra Pradesh   31-05-2019    Monthly                              3.65  \
# 1    Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2    Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3    Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4    Andhra Pradesh   30-09-2019    Monthly                              5.17
# ..              ...          ...        ...                               ...
# 763             NaN          NaN        NaN                               NaN
# 764             NaN          NaN        NaN                               NaN
# 765             NaN          NaN        NaN                               NaN
# 766             NaN          NaN        NaN                               NaN
# 767             NaN          NaN        NaN                               NaN
#
# ...

# %%
df.isnull().sum()
# Out:
# Region                                      28
#  Date                                       28
#  Frequency                                  28
#  Estimated Unemployment Rate (%)            28
#  Estimated Employed                         28
#  Estimated Labour Participation Rate (%)    28
# Area                                        28
# dtype: int64

# %%
df1= df.dropna()

# %%
df1.isnull().sum()
# Out:
# Region                                      0
#  Date                                       0
#  Frequency                                  0
#  Estimated Unemployment Rate (%)            0
#  Estimated Employed                         0
#  Estimated Labour Participation Rate (%)    0
# Area                                        0
# dtype: int64

# %%
df1.Area.unique()
# Out:
# array(['Rural', 'Urban'], dtype=object)

# %%
df1.columns = ["Region", "Date", "Frequency",	"Estimated Unemployment Rate (%)",
               "Estimated Employed",	"Estimated Labour Participation Rate (%)",	"Area"]
plt.title("Estimated Employed in Rural v/s Urban")
sns.histplot(x="Estimated Employed", hue="Area", data=df1)
plt.show()

# %%
df1.columns = ["Region", "Date", "Frequency",	"Estimated Unemployment Rate (%)",
               "Estimated Employed",	"Estimated Labour Participation Rate (%)",	"Area"]
plt.title("Unemployment Representation")
sns.histplot(x="Estimated Unemployment Rate (%)", hue="Region", data=df1)
plt.show()

# %%
df1.columns = ["Region", "Date", "Frequency",	"Estimated Unemployment Rate (%)",
               "Estimated Employed",	"Estimated Labour Participation Rate (%)",	"Area"]
plt.title("Estimated Unemployed in Rural v/s Urban")
sns.histplot(x="Estimated Unemployment Rate (%)", hue="Area", data=df1)
plt.show()

# %%
unemployment= df1[["Area","Region","Estimated Unemployment Rate (%)"]]
figure=px.sunburst(unemployment, path=["Area","Region"], values="Estimated Unemployment Rate (%)",
                  width=700, height=700,color_continuous_scale="RdY1Gn",
                   title="Unemployment Rate in India(Rural and Urban Oriented)")
figure.show()

# %%
unemployment= df1[["Region","Area","Estimated Unemployment Rate (%)"]]
figure=px.sunburst(unemployment, path=["Region","Area"], values="Estimated Unemployment Rate (%)",
                  width=700, height=700,color_continuous_scale="RdY1Gn",
                   title="Unemployment Rate in India")
figure.show()
